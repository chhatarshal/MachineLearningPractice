# %%
import gym
import numpy as np

# %%
import numpy as np
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class ActorCriticNetwork(nn.Module):
    def __init__(self, lr, input_dims, n_actions, fc1_dims=256, fc2_dims=256):
        super(ActorCriticNetwork, self).__init__()
        self.fc1 = nn.Linear(*input_dims, fc1_dims)
        self.fc2 = nn.Linear(fc1_dims, fc2_dims)
        self.pi = nn.Linear(fc2_dims, n_actions)
        self.v = nn.Linear(fc2_dims, 1)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        pi = self.pi(x)
        v = self.v(x)

        return (pi, v)

# %%
class Agent():
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions, 
                 gamma=0.99):
        self.gamma = gamma
        self.lr = lr
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.actor_critic = ActorCriticNetwork(lr, input_dims, n_actions, 
                                               fc1_dims, fc2_dims)
        self.log_prob = None

    def choose_action(self, observation):
        state = T.tensor([observation], dtype=T.float).to(self.actor_critic.device)
        probabilities, _ = self.actor_critic.forward(state)
        probabilities = F.softmax(probabilities, dim=1)
        action_probs = T.distributions.Categorical(probabilities)
        action = action_probs.sample()
        log_prob = action_probs.log_prob(action)
        self.log_prob = log_prob

        return action.item()

    def learn(self, state, reward, state_, done):
        self.actor_critic.optimizer.zero_grad()

        state = T.tensor([state], dtype=T.float).to(self.actor_critic.device)
        state_ = T.tensor([state_], dtype=T.float).to(self.actor_critic.device)
        reward = T.tensor(reward, dtype=T.float).to(self.actor_critic.device)

        _, critic_value = self.actor_critic.forward(state)
        _, critic_value_ = self.actor_critic.forward(state_)

        delta = reward + self.gamma*critic_value_*(1-int(done)) - critic_value

        actor_loss = -self.log_prob*delta
        critic_loss = delta**2

        (actor_loss + critic_loss).backward()
        self.actor_critic.optimizer.step()

# %%
if __name__ == '__main__':
    env = gym.make('LunarLander-v2')
    agent = Agent(gamma=0.99, lr=5e-6, input_dims=[8], n_actions=4,
                  fc1_dims=2048, fc2_dims=1536)
    n_games = 500

    fname = 'ACTOR_CRITIC_' + 'lunar_lander_' + str(agent.fc1_dims) + \
            '_fc1_dims_' + str(agent.fc2_dims) + '_fc2_dims_lr' + str(agent.lr) +\
            '_' + str(n_games) + 'games'
    figure_file = 'plots/' + fname + '.png'

    scores = []
    for i in range(n_games):
        done = False
        observation = env.reset()
        score = 0
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent.learn(observation, reward, observation_, done)
            observation = observation_
        scores.append(score)

        avg_score = np.mean(scores[-100:])
        print('episode ', i, 'score %.1f' % score,
                'average score %.1f' % avg_score)

    x = [i+1 for i in range(n_games)]
# Out:
# episode  0 score -143.5 average score -143.5
# episode  1 score -96.8 average score -120.2
# episode  2 score -447.8 average score -229.4
# episode  3 score -244.6 average score -233.2
# episode  4 score -201.8 average score -226.9
# episode  5 score -91.4 average score -204.3
# episode  6 score -79.6 average score -186.5
# episode  7 score -153.8 average score -182.4
# episode  8 score -81.6 average score -171.2
# episode  9 score -401.6 average score -194.3
# episode  10 score -368.9 average score -210.1
# episode  11 score -193.9 average score -208.8
# episode  12 score -103.8 average score -200.7
# episode  13 score -85.7 average score -192.5
# episode  14 score -68.7 average score -184.2
# episode  15 score -45.6 average score -175.6
# episode  16 score -197.8 average score -176.9
# episode  17 score -101.5 average score -172.7
# episode  18 score -260.6 average score -177.3
# episode  19 score -217.7 average score -179.3
# episode  20 score -43.9 average score -172.9
# episode  21 score -133.5 average score -171.1
# episode  22 score -233.0 average score -173.8
# episode  23 score -200.7 average score -174.9
# episode  24 score -224.4 average score -176.9
# episode  25 score -183.0 average score -177.1
# episode  26 score -479.3 average score -188.3
# episode  27 score -413.6 average score -196.4
# episode  28 score -389.4 average score -203.0
# episode  29 score -702.5 average score -219.7
# episode  30 score -440.4 average score -226.8
# episode  31 score -258.0 average score -227.8
# episode  32 score -314.5 average score -230.4
# episode  33 score -239.2 average score -230.6
# episode  34 score -274.7 average score -231.9
# episode  35 score -220.2 average score -231.6
# episode  36 score -333.1 average score -234.3
# episode  37 score -305.6 average score -236.2
# episode  38 score -290.1 average score -237.6
# episode  39 score -47.1 average score -232.8
# episode  40 score -247.7 average score -233.2
# episode  41 score -401.9 average score -237.2
# episode  42 score -434.0 average score -241.8
# episode  43 score -60.0 average score -237.6
# episode  44 score -282.6 average score -238.6
# episode  45 score -257.2 average score -239.1
# episode  46 score -39.6 average score -234.8
# episode  47 score -107.4 average score -232.2
# episode  48 score -143.8 average score -230.3
# episode  49 score -292.5 average score -231.6
# episode  50 score -217.3 average score -231.3
# episode  51 score -306.6 average score -232.8
# episode  52 score -182.4 average score -231.8
# episode  53 score -254.3 average score -232.2
# episode  54 score -675.8 average score -240.3
# episode  55 score -247.0 average score -240.4
# episode  56 score -30.4 average score -236.7
# episode  57 score -332.1 average score -238.4
# episode  58 score -298.8 average score -239.4
# episode  59 score -245.3 average score -239.5
# episode  60 score -205.1 average score -238.9
# episode  61 score -447.3 average score -242.3
# episode  62 score -240.8 average score -242.3
# episode  63 score -239.3 average score -242.2
# episode  64 score -365.6 average score -244.1
# episode  65 score -270.6 average score -244.5
# episode  66 score -128.1 average score -242.8
# episode  67 score -235.5 average score -242.7
# episode  68 score 3.1 average score -239.1
# episode  69 score -54.4 average score -236.5
# episode  70 score -272.9 average score -237.0
# episode  71 score -252.4 average score -237.2
# episode  72 score -305.7 average score -238.1
# episode  73 score -225.8 average score -238.0
# episode  74 score -289.6 average score -238.7
# episode  75 score -272.1 average score -239.1
# episode  76 score -179.0 average score -238.3
# episode  77 score -15.6 average score -235.5
# episode  78 score -342.1 average score -236.8
# episode  79 score -251.0 average score -237.0
# episode  80 score -288.0 average score -237.6
# episode  81 score -249.2 average score -237.8
# episode  82 score -232.8 average score -237.7
# episode  83 score -57.8 average score -235.6
# episode  84 score -475.6 average score -238.4
# episode  85 score -37.6 average score -236.1
# episode  86 score -71.3 average score -234.2
# episode  87 score -186.4 average score -233.6
# episode  88 score -109.2 average score -232.2
# episode  89 score -340.4 average score -233.4
# episode  90 score -278.2 average score -233.9
# episode  91 score -86.1 average score -232.3
# episode  92 score -265.9 average score -232.7
# episode  93 score -199.5 average score -232.3
# episode  94 score -78.3 average score -230.7
# episode  95 score -156.6 average score -229.9
# episode  96 score -103.7 average score -228.6
# episode  97 score -264.0 average score -229.0
# episode  98 score -75.7 average score -227.4
# episode  99 score -284.8 average score -228.0
# episode  100 score -294.5 average score -229.5
# episode  101 score -361.4 average score -232.2
# episode  102 score -237.5 average score -230.1
# episode  103 score -59.9 average score -228.2
# episode  104 score -102.1 average score -227.2
# episode  105 score -267.6 average score -229.0
# episode  106 score -30.4 average score -228.5
# episode  107 score -203.3 average score -229.0
# episode  108 score -267.5 average score -230.8
# episode  109 score -329.3 average score -230.1
# episode  110 score -257.7 average score -229.0
# episode  111 score -115.1 average score -228.2
# episode  112 score -95.9 average score -228.1
# episode  113 score -287.0 average score -230.2
# episode  114 score -390.0 average score -233.4
# episode  115 score -307.7 average score -236.0
# episode  116 score -317.4 average score -237.2
# episode  117 score -1.0 average score -236.2
# episode  118 score -179.0 average score -235.4
# episode  119 score -353.1 average score -236.7
# episode  120 score -138.1 average score -237.7
# episode  121 score -236.5 average score -238.7
# episode  122 score 24.8 average score -236.1
# episode  123 score -88.8 average score -235.0
# episode  124 score -280.5 average score -235.5
# episode  125 score -193.3 average score -235.7
# episode  126 score -279.1 average score -233.6
# episode  127 score -152.3 average score -231.0
# episode  128 score -77.5 average score -227.9
# episode  129 score -195.4 average score -222.8
# episode  130 score -284.7 average score -221.3
# episode  131 score -146.9 average score -220.2
# episode  132 score -87.4 average score -217.9
# episode  133 score -210.4 average score -217.6
# episode  134 score -325.1 average score -218.1
# episode  135 score -339.4 average score -219.3
# episode  136 score -116.3 average score -217.1
# episode  137 score -168.8 average score -215.8
# episode  138 score -151.1 average score -214.4
# episode  139 score -253.5 average score -216.5
# episode  140 score -323.4 average score -217.2
# episode  141 score 38.4 average score -212.8
# episode  142 score -119.5 average score -209.7
# episode  143 score -84.4 average score -209.9
# episode  144 score -292.9 average score -210.0
# episode  145 score -125.2 average score -208.7
# episode  146 score -227.6 average score -210.6
# episode  147 score -28.6 average score -209.8
# episode  148 score -168.0 average score -210.0
# episode  149 score -364.2 average score -210.7
# episode  150 score -168.1 average score -210.3
# episode  151 score -242.3 average score -209.6
# episode  152 score -69.8 average score -208.5
# episode  153 score -226.1 average score -208.2
# episode  154 score -49.9 average score -201.9
# episode  155 score -38.4 average score -199.9
# episode  156 score -62.1 average score -200.2
# episode  157 score -262.8 average score -199.5
# episode  158 score -188.7 average score -198.4
# episode  159 score -33.6 average score -196.3
# episode  160 score -175.4 average score -196.0
# episode  161 score -294.6 average score -194.4
# episode  162 score -211.7 average score -194.1
# episode  163 score -28.4 average score -192.0
# episode  164 score -238.7 average score -190.8
# episode  165 score -229.5 average score -190.4
# episode  166 score -111.6 average score -190.2
# episode  167 score -102.0 average score -188.9
# episode  168 score -153.7 average score -190.4
# episode  169 score -212.0 average score -192.0
# episode  170 score 29.0 average score -189.0
# episode  171 score -236.6 average score -188.8
# episode  172 score -190.2 average score -187.7
# episode  173 score -70.1 average score -186.1
# episode  174 score 20.6 average score -183.0
# episode  175 score -214.7 average score -182.4
# episode  176 score -294.1 average score -183.6
# episode  177 score -305.6 average score -186.5
# episode  178 score -225.6 average score -185.3
# episode  179 score -186.2 average score -184.7
# episode  180 score -239.9 average score -184.2
# episode  181 score -90.8 average score -182.6
# episode  182 score -54.8 average score -180.8
# episode  183 score 50.9 average score -179.7
# episode  184 score -245.5 average score -177.4
# episode  185 score -125.8 average score -178.3
# episode  186 score -277.7 average score -180.4
# episode  187 score 23.1 average score -178.3
# episode  188 score -161.3 average score -178.8
# episode  189 score -124.7 average score -176.7
# episode  190 score -51.5 average score -174.4
# episode  191 score -261.9 average score -176.1
# episode  192 score -238.4 average score -175.9
# episode  193 score -43.6 average score -174.3
# episode  194 score -126.4 average score -174.8
# episode  195 score -243.4 average score -175.7
# episode  196 score -186.4 average score -176.5
# episode  197 score -135.1 average score -175.2
# episode  198 score -91.9 average score -175.4
# episode  199 score -150.9 average score -174.0
# episode  200 score -48.9 average score -171.6
# episode  201 score -285.6 average score -170.8
# episode  202 score -273.4 average score -171.2
# episode  203 score -64.0 average score -171.2
# episode  204 score -92.9 average score -171.1
# episode  205 score -129.0 average score -169.7
# episode  206 score -208.5 average score -171.5
# episode  207 score -68.0 average score -170.2
# episode  208 score -162.7 average score -169.1
# episode  209 score -59.2 average score -166.4
# episode  210 score -20.2 average score -164.0
# episode  211 score -101.0 average score -163.9
# episode  212 score -50.2 average score -163.4
# episode  213 score -4.4 average score -160.6
# episode  214 score -242.6 average score -159.1
# episode  215 score -248.7 average score -158.5
# episode  216 score -129.5 average score -156.7
# episode  217 score 65.6 average score -156.0
# episode  218 score -49.5 average score -154.7
# episode  219 score -210.8 average score -153.3
# episode  220 score -264.4 average score -154.5
# episode  221 score -145.8 average score -153.6
# episode  222 score -208.6 average score -156.0
# episode  223 score -63.5 average score -155.7
# episode  224 score -330.1 average score -156.2
# episode  225 score -223.9 average score -156.5
# episode  226 score 77.9 average score -152.9
# episode  227 score -208.4 average score -153.5
# episode  228 score 117.8 average score -151.6
# episode  229 score -241.1 average score -152.0
# episode  230 score -244.9 average score -151.6
# episode  231 score 10.0 average score -150.0
# episode  232 score -22.6 average score -149.4
# episode  233 score -198.4 average score -149.3
# episode  234 score -177.3 average score -147.8
# episode  235 score -183.9 average score -146.2
# episode  236 score -182.5 average score -146.9
# episode  237 score -188.0 average score -147.1
# episode  238 score -113.4 average score -146.7
# episode  239 score -5.9 average score -144.2
# episode  240 score -185.9 average score -142.9
# episode  241 score 25.7 average score -143.0
# episode  242 score -130.6 average score -143.1
# episode  243 score -243.0 average score -144.7
# episode  244 score -30.6 average score -142.1
# episode  245 score -166.9 average score -142.5
# episode  246 score -132.4 average score -141.5
# episode  247 score -38.4 average score -141.6
# episode  248 score -224.9 average score -142.2
# episode  249 score -48.0 average score -139.0
# episode  250 score -11.5 average score -137.5
# episode  251 score -232.8 average score -137.4
# episode  252 score -224.1 average score -138.9
# episode  253 score -240.4 average score -139.1
# episode  254 score -83.1 average score -139.4
# episode  255 score -186.8 average score -140.9
# episode  256 score 21.4 average score -140.0
# episode  257 score -53.9 average score -138.0
# episode  258 score -305.7 average score -139.1
# episode  259 score -49.3 average score -139.3
# episode  260 score -56.2 average score -138.1
# episode  261 score -165.0 average score -136.8
# episode  262 score -76.1 average score -135.4
# episode  263 score -45.8 average score -135.6
# episode  264 score -85.9 average score -134.1
# episode  265 score -56.4 average score -132.4
# episode  266 score -55.8 average score -131.8
# episode  267 score -27.4 average score -131.1
# episode  268 score -57.1 average score -130.1
# episode  269 score -209.3 average score -130.1
# episode  270 score -252.4 average score -132.9
# episode  271 score -97.3 average score -131.5
# episode  272 score 97.9 average score -128.6
# episode  273 score 42.9 average score -127.5
# episode  274 score -202.5 average score -129.7
# episode  275 score -28.6 average score -127.8
# episode  276 score -78.6 average score -125.7
# episode  277 score -206.8 average score -124.7
# episode  278 score -238.0 average score -124.8
# episode  279 score -55.2 average score -123.5
# episode  280 score -89.4 average score -122.0
# episode  281 score -112.3 average score -122.2
# episode  282 score -21.2 average score -121.9
# episode  283 score -256.4 average score -125.0
# episode  284 score -51.9 average score -123.0
# episode  285 score 20.5 average score -121.6
# episode  286 score -252.8 average score -121.3
# episode  287 score -231.0 average score -123.8
# episode  288 score -257.4 average score -124.8
# episode  289 score -83.8 average score -124.4
# episode  290 score 6.4 average score -123.8
# episode  291 score -10.1 average score -121.3
# episode  292 score -75.9 average score -119.7
# episode  293 score 62.7 average score -118.6
# episode  294 score -32.5 average score -117.7
# episode  295 score 121.4 average score -114.0
# episode  296 score 75.2 average score -111.4
# episode  297 score -285.2 average score -112.9
# episode  298 score -16.2 average score -112.2
# episode  299 score -141.7 average score -112.1
# episode  300 score -163.8 average score -113.2
# episode  301 score -130.5 average score -111.7
# episode  302 score -230.2 average score -111.2
# episode  303 score -175.2 average score -112.3
# episode  304 score -230.9 average score -113.7
# episode  305 score -43.7 average score -112.9
# episode  306 score 161.2 average score -109.2
# episode  307 score -251.4 average score -111.0
# episode  308 score 164.5 average score -107.7
# episode  309 score 12.2 average score -107.0
# episode  310 score -252.8 average score -109.4
# episode  311 score 194.1 average score -106.4
# episode  312 score -81.5 average score -106.7
# episode  313 score 48.0 average score -106.2
# episode  314 score -191.5 average score -105.7
# episode  315 score -292.7 average score -106.1
# episode  316 score -165.2 average score -106.5
# episode  317 score -239.2 average score -109.5
# episode  318 score 29.2 average score -108.7
# episode  319 score -239.1 average score -109.0
# episode  320 score -198.6 average score -108.4
# episode  321 score -59.7 average score -107.5
# episode  322 score 235.5 average score -103.1
# episode  323 score 80.3 average score -101.6
# episode  324 score -215.6 average score -100.5
# episode  325 score 185.3 average score -96.4
# episode  326 score -245.1 average score -99.6
# episode  327 score -86.0 average score -98.4
# episode  328 score -81.5 average score -100.4
# episode  329 score -259.4 average score -100.6
# episode  330 score -115.5 average score -99.3
# episode  331 score -224.1 average score -101.6
# episode  332 score -235.1 average score -103.7
# episode  333 score -183.8 average score -103.6
# episode  334 score -113.2 average score -103.0
# episode  335 score -173.6 average score -102.8
# episode  336 score 81.0 average score -100.2
# episode  337 score 167.6 average score -96.7
# episode  338 score -246.1 average score -98.0
# episode  339 score -47.4 average score -98.4
# episode  340 score -210.8 average score -98.6
# episode  341 score -235.8 average score -101.3
# episode  342 score 79.9 average score -99.2
# episode  343 score -46.8 average score -97.2
# episode  344 score -199.9 average score -98.9
# episode  345 score 100.8 average score -96.2
# episode  346 score -160.7 average score -96.5
# episode  347 score -70.0 average score -96.8
# episode  348 score 130.7 average score -93.3
# episode  349 score -164.3 average score -94.4
# episode  350 score -13.9 average score -94.4
# episode  351 score -66.7 average score -92.8
# episode  352 score -42.8 average score -91.0
# episode  353 score 120.4 average score -87.4
# episode  354 score 35.7 average score -86.2
# episode  355 score -251.7 average score -86.8
# episode  356 score -232.8 average score -89.4
# episode  357 score -88.0 average score -89.7
# episode  358 score -22.3 average score -86.9
# episode  359 score -165.7 average score -88.0
# episode  360 score -130.5 average score -88.8
# episode  361 score 4.1 average score -87.1
# episode  362 score -43.8 average score -86.8
# episode  363 score -224.8 average score -88.6
# episode  364 score -235.3 average score -90.0
# episode  365 score -10.8 average score -89.6
# episode  366 score -251.8 average score -91.5
# episode  367 score -146.7 average score -92.7
# episode  368 score -62.9 average score -92.8
# episode  369 score -235.2 average score -93.1
# episode  370 score -233.0 average score -92.9
# episode  371 score -189.6 average score -93.8
# episode  372 score 56.2 average score -94.2
# episode  373 score -96.1 average score -95.6
# episode  374 score -3.4 average score -93.6
# episode  375 score -14.6 average score -93.5
# episode  376 score -26.8 average score -92.9
# episode  377 score 49.3 average score -90.4
# episode  378 score 61.2 average score -87.4
# episode  379 score -120.9 average score -88.1
# episode  380 score -90.2 average score -88.1
# episode  381 score -14.2 average score -87.1
# episode  382 score -64.3 average score -87.5
# episode  383 score -200.5 average score -86.9
# episode  384 score -221.9 average score -88.6
# episode  385 score 139.8 average score -87.5
# episode  386 score -164.4 average score -86.6
# episode  387 score -6.5 average score -84.3
# episode  388 score -15.9 average score -81.9
# episode  389 score 76.2 average score -80.3
# episode  390 score -253.0 average score -82.9
# episode  391 score -39.2 average score -83.2
# episode  392 score -287.7 average score -85.3
# episode  393 score 109.5 average score -84.8
# episode  394 score 26.4 average score -84.3
# episode  395 score 206.6 average score -83.4
# episode  396 score -217.1 average score -86.3
# episode  397 score -26.4 average score -83.7
# episode  398 score -4.4 average score -83.6
# episode  399 score -58.9 average score -82.8
# episode  400 score -168.3 average score -82.8
# episode  401 score -27.4 average score -81.8
# episode  402 score 0.1 average score -79.5
# episode  403 score 201.2 average score -75.7
# episode  404 score 118.6 average score -72.2
# episode  405 score -4.0 average score -71.9
# episode  406 score -67.7 average score -74.1
# episode  407 score -216.3 average score -73.8
# episode  408 score -59.7 average score -76.0
# episode  409 score 116.6 average score -75.0
# episode  410 score -177.3 average score -74.2
# episode  411 score -71.1 average score -76.9
# episode  412 score -98.4 average score -77.1
# episode  413 score -50.5 average score -78.0
# episode  414 score -95.9 average score -77.1
# episode  415 score 152.8 average score -72.6
# episode  416 score -211.3 average score -73.1
# episode  417 score -264.0 average score -73.3
# episode  418 score -79.0 average score -74.4
# episode  419 score 48.0 average score -71.5
# episode  420 score -223.0 average score -71.8
# episode  421 score -13.5 average score -71.3
# episode  422 score 87.3 average score -72.8
# episode  423 score 113.5 average score -72.5
# episode  424 score -100.0 average score -71.3
# episode  425 score -57.7 average score -73.8
# episode  426 score 4.6 average score -71.3
# episode  427 score 183.4 average score -68.6
# episode  428 score -269.6 average score -70.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f86fffe9cd38> in <module>
#      19             observation_, reward, done, info = env.step(action)
#      20             score += reward
# ---> 21             agent.learn(observation, reward, observation_, done)
#      22             observation = observation_
#      23         scores.append(score)
#
# <ipython-input-3-fdaf8c277ff0> in learn(self, state, reward, state_, done)
#      36         critic_loss = delta**2
#      37
# ---> 38         (actor_loss + critic_loss).backward()
#      39         self.actor_critic.optimizer.step()
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:
